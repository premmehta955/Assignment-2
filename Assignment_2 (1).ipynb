# %%
Q1. How can we store a single quote(') as a string in a variable?
    Answer: We can store a single quote(') as a string in a variable as present it between two double quote.

Q2. Refer the below variable: x='a' here, is x a character type or string type variable? Support your answer with an explanation.
    Answer: If "x" is defined as a single character using single quotes('x'), it would be considered a character type variable.
           In Python, individual characters are treated as strings of length one. So, even it is a single character, 
          it is still considered a string.
            
            Program input: x='a' print(type(x))
            #Program Output: <class 'str'>(string type)

Q3. Apply the following function on this variable:'Welcome to Python foundation course'

 1. find()
    # Program input: a='Welcome to Python foundation course'
        print(a.find('o'))
    # Program output: 4

 2. count()

  # Program input:
   a='Welcome to Python foundation course'
    print(a.count(a))  
  # Program output: 1


  3. len()
  # Program input:
    a='Welcome to Python foundation course'
    print(len(a)
  # Program output: 35

   4. concatenation
   # Program input: 
      a='Welcome to '
      b='Python foundation course'
      print(a+b)
    # Program output: Welcome to Python foundation course
Q4. For the variable: word='PanaJi@12256' calculate the following:
          a. Total number of alphabets in lower case  
          # Prgram input: word='PanaJi@12256' 
          
          lcase = sum(d.islower() for d in word) 
          print(lcase)
          #Program Output:4

b. Total number of alphabets in uppercase
    #Program input:
        word='PanaJi@12256'
        ucase=sum(e.isupper() for e in word)
        print(ucase)
    #Program Output:2
c. Total number of numberical in string 
    #Program input:
        word='PanaJi@12256'
        digitscase = sum(c.isdigit() for c in word)
        print(digitscase)
    #Program Output:5
# Q5. Write a code to store a numerical value inside a variable then convert it into string.
#     # Program input:
       a =98
        b=str(a)
        print(type(b))
